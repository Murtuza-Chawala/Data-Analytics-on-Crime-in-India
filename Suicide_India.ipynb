# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('Suicides in India 2001-2012.csv')

# %%
df.head(130)
# Out:
#              State  Year Type_code                                      Type  \
# 0    A & N Islands  2001    Causes                        Illness (Aids/STD)
# 1    A & N Islands  2001    Causes   Bankruptcy or Sudden change in Economic
# 2    A & N Islands  2001    Causes   Cancellation/Non-Settlement of Marriage
# 3    A & N Islands  2001    Causes         Physical Abuse (Rape/Incest Etc.)
# 4    A & N Islands  2001    Causes                             Dowry Dispute
# 5    A & N Islands  2001    Causes                           Family Problems
# 6    A & N Islands  2001    Causes       Ideological Causes/Hero Worshipping
# 7    A & N Islands  2001    Causes                   Other Prolonged Illness
# 8    A & N Islands  2001    Causes                          Property Dispute
# 9    A & N Islands  2001    Causes                 Fall in Social Reputation
# 10   A & N Islands  2001    Causes                    Illegitimate Pregnancy
# ...

# %%
df.loc[46865] #Random record
# Out:
# State                                   Chhattisgarh
# Year                                            2012
# Type_code                                     Causes
# Type         Bankruptcy or Sudden change in Economic
# Gender                                          Male
# Age_group                                      30-44
# Total                                              3
# Name: 46865, dtype: object

# %%
df.describe() # 2 lakh 37 k records
# Out:
#                 Year          Total
# count  237519.000000  237519.000000
# mean     2006.500448      55.034477
# std         3.452240     792.749038
# min      2001.000000       0.000000
# 25%      2004.000000       0.000000
# 50%      2007.000000       0.000000
# 75%      2010.000000       6.000000
# max      2012.000000   63343.000000

# %%
df.columns
# Out:
# Index(['State', 'Year', 'Type_code', 'Type', 'Gender', 'Age_group', 'Total'], dtype='object')

# %%
df['State'].value_counts().head()
# Out:
# Maharashtra       6792
# Madhya Pradesh    6792
# Karnataka         6792
# Andhra Pradesh    6791
# Rajasthan         6791
# Name: State, dtype: int64

# %%
df['Age_group'].value_counts().head()
# Out:
# 15-29    45223
# 30-44    45193
# 45-59    45146
# 60+      45074
# 0-14     45027
# Name: Age_group, dtype: int64

# %%
df['Type'].value_counts()
# Out:
# Others (Please Specify)                           7263
# Fall in Social Reputation                         4200
# Failure in Examination                            4200
# By Consuming Insecticides                         4200
# By Jumping from (Other sites)                     4200
# House Wife                                        4200
# Farming/Agriculture Activity                      4200
# Ideological Causes/Hero Worshipping               4200
# Divorce                                           4200
# Suspected/Illicit Relation                        4200
# By Drowning                                       4200
# By Machine                                        4200
# Other Causes (Please Specity)                     4200
# Student                                           4200
# By Consuming Other Poison                         4200
# By touching electric wires                        4200
# Illness (Aids/STD)                                4200
# ...

# %%
young =  df[(df['Age_group'] == '0-14') & (df['State'] == 'Maharashtra')]
young.head()
# Out:
#               State  Year Type_code                                 Type  \
# 135190  Maharashtra  2001    Causes  Ideological Causes/Hero Worshipping
# 135191  Maharashtra  2001    Causes                 Drug Abuse/Addiction
# 135192  Maharashtra  2001    Causes            Fall in Social Reputation
# 135193  Maharashtra  2001    Causes              Insanity/Mental Illness
# 135194  Maharashtra  2001    Causes                              Divorce
#
#         Gender Age_group  Total
# 135190  Female      0-14      0
# 135191  Female      0-14      0
# 135192  Female      0-14      0
# 135193  Female      0-14     12
# 135194  Female      0-14      0

# %%
young['Type_code'].value_counts().head()
# Out:
# Causes                  624
# Means_adopted           384
# Professional_Profile    288
# Name: Type_code, dtype: int64

# %%
x = df[df['Type'] == 'Love Affairs']['Total']
x.sum()
# Out:
# 45039

# %%
x = df[df['Type'] == 'Divorce']['Total']
x.sum()
# Out:
# 4133

# %%
x = df[df['Type'] == 'Failure in Examination']['Total']
#x.head().sum()
x.sum()
# Out:
# 27005

# %% [markdown]
# ### Love affairs

# %%
love = df[df['Type'] == 'Love Affairs']

# %%
love.head(20)
# Out:
#              State  Year Type_code          Type  Gender Age_group  Total
# 13   A & N Islands  2001    Causes  Love Affairs  Female      0-14      1
# 42   A & N Islands  2001    Causes  Love Affairs    Male      0-14      0
# 65   A & N Islands  2001    Causes  Love Affairs  Female     15-29      0
# 89   A & N Islands  2001    Causes  Love Affairs    Male     15-29      3
# 128  A & N Islands  2001    Causes  Love Affairs  Female     30-44      0
# 133  A & N Islands  2001    Causes  Love Affairs    Male     30-44      0
# 177  A & N Islands  2001    Causes  Love Affairs  Female     45-59      0
# 205  A & N Islands  2001    Causes  Love Affairs    Male     45-59      0
# 223  A & N Islands  2001    Causes  Love Affairs  Female       60+      0
# 242  A & N Islands  2001    Causes  Love Affairs    Male       60+      0
# 567  A & N Islands  2002    Causes  Love Affairs  Female      0-14      0
# 607  A & N Islands  2002    Causes  Love Affairs    Male      0-14      0
# ...

# %%
#love_age = love.loc['Total']
love['Total'].sum()
# Out:
# 45039

# %%
Group = love.groupby("Age_group")

# %%
Group['Total'].sum() # 73% 33,023 people committed suicide in India due to love affairs were from age of 15-29 years.
# Out:
# Age_group
# 0-14      1250
# 15-29    33023
# 30-44     9866
# 45-59      862
# 60+         38
# Name: Total, dtype: int64

# %%
#gender = love.groupby("Gender")
#gender.sum()
#gender['Total'].sum()
#Or
love.groupby("Gender")['Total'].sum()
# Out:
# Gender
# Female    21339
# Male      23700
# Name: Total, dtype: int64

# %%
year = love.groupby("Year")
year['Total'].sum()
# Out:
# Year
# 2001    3114
# 2002    3101
# 2003    3996
# 2004    3799
# 2005    3496
# 2006    4064
# 2007    3383
# 2008    3774
# 2009    3711
# 2010    4166
# 2011    4586
# 2012    3849
# Name: Total, dtype: int64

# %%
love.groupby("State")['Total'].sum().sort_values(ascending = False)
# Out:
# State
# West Bengal          9606
# Tamil Nadu           5684
# Assam                4852
# Andhra Pradesh       3325
# Maharashtra          2872
# Odisha               2585
# Gujarat              2318
# Madhya Pradesh       2303
# Uttar Pradesh        2166
# Karnataka            1701
# Chhattisgarh         1306
# Kerala               1223
# Rajasthan            1109
# Tripura               812
# Delhi (Ut)            584
# Bihar                 478
# Haryana               429
# Jharkhand             408
# Himachal Pradesh      216
# Goa                   194
# Punjab                185
# Uttarakhand           151
# Jammu & Kashmir       121
# Puducherry             88
# A & N Islands          75
# Sikkim                 47
# Meghalaya              47
# D & N Haveli           42
# Chandigarh             41
# Arunachal Pradesh      27
# Manipur                19
# Daman & Diu            12
# Mizoram                 7
# Nagaland                6
# Lakshadweep             0
# ...

# %%
#In the state of West Bengal how many suic.. due to love issue based on their Gender
love[love['State'] == 'West Bengal'].groupby("Gender")['Total'].sum()
# Out:
# Gender
# Female    4872
# Male      4734
# Name: Total, dtype: int64

# %%
z =  lambda x: love[love['State'] == x].groupby("Gender")['Total'].sum()

# %%
states =  love['State'].unique()

# %%
love['State'].unique().apply(z)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-146-56246fa2458a> in <module>
# ----> 1 love['State'].unique().apply(z)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'apply'

# %%
z('Andhra Pradesh')
# Out:
# Gender
# Female    1377
# Male      1948
# Name: Total, dtype: int64

# %%
z('Goa')
# Out:
# Gender
# Female     93
# Male      101
# Name: Total, dtype: int64

# %%
z(states)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-157-653d79cfdcdd> in <module>
# ----> 1 z(states)
#
# <ipython-input-141-a78b51437686> in <lambda>(x)
# ----> 1 z =  lambda x: love[love['State'] == x].groupby("Gender")['Total'].sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1251             # as it will broadcast
#    1252             if other.ndim != 0 and len(self) != len(other):
# -> 1253                 raise ValueError('Lengths must match to compare')
#    1254
#    1255             res_values = na_op(self.values, np.asarray(other))
#
# ValueError: Lengths must match to compare

# %%
type(states)
# Out:
# numpy.ndarray

# %%
state = np.array(states)
type(state)
# Out:
# numpy.ndarray

# %%
states = pd.DataFrame(states)
type(states)
# Out:
# pandas.core.frame.DataFrame

# %%
states
# Out:
#                     0
# 0       A & N Islands
# 1      Andhra Pradesh
# 2   Arunachal Pradesh
# 3               Assam
# 4               Bihar
# 5          Chandigarh
# 6        Chhattisgarh
# 7        D & N Haveli
# 8         Daman & Diu
# 9          Delhi (Ut)
# 10                Goa
# 11            Gujarat
# 12            Haryana
# 13   Himachal Pradesh
# 14    Jammu & Kashmir
# 15          Jharkhand
# 16          Karnataka
# 17             Kerala
# 18        Lakshadweep
# 19     Madhya Pradesh
# 20        Maharashtra
# 21            Manipur
# 22          Meghalaya
# 23            Mizoram
# 24           Nagaland
# 25             Odisha
# 26         Puducherry
# 27             Punjab
# 28          Rajasthan
# 29             Sikkim
# 30         Tamil Nadu
# 31            Tripura
# 32      Uttar Pradesh
# 33        Uttarakhand
# 34        West Bengal

# %%
gender =pd.concat([states[0],score],axis=1,names=['State'])

# %%
score =  states[0].apply(z)

# %%
gender
# Out:
#                     0  Female  Male
# 0       A & N Islands      23    52
# 1      Andhra Pradesh    1377  1948
# 2   Arunachal Pradesh      13    14
# 3               Assam    1858  2994
# 4               Bihar     255   223
# 5          Chandigarh      20    21
# 6        Chhattisgarh     588   718
# 7        D & N Haveli      21    21
# 8         Daman & Diu       8     4
# 9          Delhi (Ut)     303   281
# 10                Goa      93   101
# 11            Gujarat    1120  1198
# 12            Haryana     141   288
# 13   Himachal Pradesh     106   110
# 14    Jammu & Kashmir      63    58
# 15          Jharkhand     224   184
# 16          Karnataka     720   981
# 17             Kerala     608   615
# 18        Lakshadweep       0     0
# 19     Madhya Pradesh    1170  1133
# 20        Maharashtra    1303  1569
# 21            Manipur      11     8
# 22          Meghalaya      19    28
# 23            Mizoram       4     3
# 24           Nagaland       5     1
# ...

# %%
gender[gender['Female'] > gender['Male']]
# Out:
#                   0  Female  Male
# 4             Bihar     255   223
# 8       Daman & Diu       8     4
# 9        Delhi (Ut)     303   281
# 14  Jammu & Kashmir      63    58
# 15        Jharkhand     224   184
# 19   Madhya Pradesh    1170  1133
# 21          Manipur      11     8
# 23          Mizoram       4     3
# 24         Nagaland       5     1
# 25           Odisha    1392  1193
# 34      West Bengal    4872  4734

# %%
df[df['State']== 'Total (Uts)']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7b9d930f34af> in <module>
# ----> 1 df[df['State']== 'Total (Uts)']
#
# NameError: name 'df' is not defined
